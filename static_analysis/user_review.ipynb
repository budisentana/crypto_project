# %%
import pandas as pd
review_path = '/home/budi/crypto_project/crypto_code/metadata_crawling/sum_negative_review.csv'
df_rev= pd.read_csv(review_path)
df_rev
# Out:
#      Unnamed: 0                            appId  fraudulent  bugs  \
# 0             0         africa.bundle.mobile.app         187    44
# 1             1  africa.buycoins.buycoinsx.basic           3     4
# 2             2          app.bankowallet.android           3     2
# 3             3             app.elaphant.wallets           0     1
# 4             4                   app.goodcrypto           6     1
# ..          ...                              ...         ...   ...
# 354         354          usdt.org.freewallet.app          19    12
# 355         355                vip.mytokenpocket          65    51
# 356         356           xmr.org.freewallet.app         104    47
# 357         357           xrp.org.freewallet.app          36    36
# 358         358                 za.co.rockwallet           1     0
#
#      authentication  security  usability  ads_tracker  cust_support  \
# 0               128         9         34            3            17
# 1                 2         0          1            0             0
# 2                 1         0          2            0             0
# 3                 0         0          0            0             0
# 4                 2         0          2            1             0
# ..              ...       ...        ...          ...           ...
# 354              13         1          8            0            15
# 355              40         7         41            1            22
# 356              60        17          3            2            46
# 357              29         2          7            0             9
# 358               0         0          0            0             0
#
#      total_negative  total  pct_negative  pct_fraud  pct_bugs  pct_auth  \
# 0               561   5676          9.88      33.33      7.84     22.82
# 1                15     59         25.42      20.00     26.67     13.33
# 2                 9      9        100.00      33.33     22.22     11.11
# 3                 1      2         50.00       0.00    100.00      0.00
# 4                23    148         15.54      26.09      4.35      8.70
# ..              ...    ...           ...        ...       ...       ...
# 354              69    306         22.55      27.54     17.39     18.84
# 355             482   2142         22.50      13.49     10.58      8.30
# 356             297   1286         23.09      35.02     15.82     20.20
# 357             103    283         36.40      34.95     34.95     28.16
# 358               1      2         50.00     100.00      0.00      0.00
#
#      pct_sec  pct_usa  pct_ads  pct_cust
# 0       1.60     6.06     0.53      3.03
# 1       0.00     6.67     0.00      0.00
# 2       0.00    22.22     0.00      0.00
# 3       0.00     0.00     0.00      0.00
# 4       0.00     8.70     4.35      0.00
# ..       ...      ...      ...       ...
# 354     1.45    11.59     0.00     21.74
# 355     1.45     8.51     0.21      4.56
# 356     5.72     1.01     0.67     15.49
# 357     1.94     6.80     0.00      8.74
# 358     0.00     0.00     0.00      0.00
#
# [359 rows x 19 columns]
